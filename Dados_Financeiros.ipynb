# %% [markdown]
# <a href="https://colab.research.google.com/github/paulorobertolds/Bootcamp_corruption/blob/main/Dados_Financeiros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#%cd /content/drive/MyDrive/Colab Notebooks/Bootcamp/Dados

# %%
import pandas as pd
# %ls
# Out:
# sample_data/

# %%
#Ler os dados
#recDesp2003=pd.read_csv('RecDesp2003.csv')
url = "https://raw.githubusercontent.com/paulorobertolds/Bootcamp_corruption/main/RecDesp2003.csv" 
recDesp2003= pd.read_csv(url, sep=',', low_memory=False)

recDesp2003.head()
# Out:
#    CD_UF  CD_MUN  ... Desporto e Lazer Encargos Especiais
# 0     11       1  ...       113,857.84         147,237.76
# 1     11       2  ...             0.00         764,401.35
# 2     11       3  ...         6,414.40          59,092.20
# 3     11       4  ...       396,927.92         699,932.70
# 4     11       5  ...        22,716.06         194,085.47
#
# [5 rows x 192 columns]

# %%
#Criar coluna UFmuni para fazer o merge
recDesp2003['ibge UfMuni']=recDesp2003['CD_UF'].astype(str)+recDesp2003['CD_MUN'].astype(str)
for i in range(0,recDesp2003.shape[1]):
  recDesp2003['ibge UfMuni'][i]=int(recDesp2003['ibge UfMuni'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
recDesp2003.head()
recDesp2003.shape
# Out:
# (5401, 193)

# %%
url= "https://raw.githubusercontent.com/paulorobertolds/Bootcamp_corruption/main/Cod%20Siafi2003.csv"
CodSiafi2003= pd.read_csv(url, sep=',', low_memory=False)
#CodSiafi2003=pd.read_csv('Cod Siafi2003.csv')
CodSiafi2003.shape
# Out:
# (5558, 12)

# %%
print(list(CodSiafi2003.columns))
# Out:
# ['UG', 'NOME DO MUNICIPIO SIAFI', 'UF', 'MUNICÍPIO/UF', 'CdUF', 'CdMun', 'Dg', 'ibge UfMuni', 'ibge UfMuniD', 'NOME IBGE', 'Populacao', 'Nome Caixa']

# %%
findata2003=pd.merge(CodSiafi2003,recDesp2003,on='ibge UfMuni')

# %%
url="https://raw.githubusercontent.com/paulorobertolds/Bootcamp_corruption/main/Ativo2003.csv"
ativo2003= pd.read_csv(url, sep=',', low_memory=False)
#ativo2003=pd.read_csv('Ativo2003.csv')
ativo2003['ibge UfMuni']=ativo2003['CD_UF'].astype(str)+ativo2003['CD_MUN'].astype(str)
for i in range(0,ativo2003.shape[1]):
  ativo2003['ibge UfMuni'][i]=int(ativo2003['ibge UfMuni'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ativo2003.shape
ativo2003.head()
ativo2003
# Out:
#       CD_UF  CD_MUN  ... Out Compensac ibge UfMuni
# 0        11       1  ...          0.00         111
# 1        11       2  ...          0.00         112
# 2        11       3  ...    310,901.71         113
# 3        11       4  ...          0.00         114
# 4        11       5  ...          0.00         115
# ...     ...     ...  ...           ...         ...
# 5396     52    2185  ...          0.00      522185
# 5397     52    2200  ...          0.00      522200
# 5398     52    2205  ...          0.00      522205
# 5399     52    2220  ...          0.00      522220
# 5400     52    2230  ...          0.00      522230
#
# [5401 rows x 60 columns]

# %%
findata2003=pd.merge(findata2003,ativo2003,on='ibge UfMuni')

# %%
findata2003.head()
findata2003.shape
# Out:
# (60, 263)

# %%
url="https://raw.githubusercontent.com/paulorobertolds/Bootcamp_corruption/main/Passivo2003.csv"
passivo2003= pd.read_csv(url, sep=',', low_memory=False)
#passivo2003=pd.read_csv('Passivo2003.csv')

# %%
passivo2003['ibge UfMuni']=passivo2003['CD_UF'].astype(str)+passivo2003['CD_MUN'].astype(str)
for i in range(0,passivo2003.shape[1]):
  passivo2003['ibge UfMuni'][i]=int(passivo2003['ibge UfMuni'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
findata2003=pd.merge(findata2003,passivo2003,on='ibge UfMuni')

# %%
findata2003.shape
pd.options.display.max_rows = 500
findata2003.isnull().sum()
# Out:
# UG                                  0
# NOME DO MUNICIPIO SIAFI             0
# UF                                  0
# MUNICÍPIO/UF                        0
# CdUF                                0
# CdMun                               0
# Dg                                  0
# ibge UfMuni                         0
# ibge UfMuniD                        0
# NOME IBGE                           0
# Populacao                           0
# Nome Caixa                          0
# CD_UF_x                             0
# CD_MUN_x                            0
# Rec Orçamentária                    0
# Rec Correntes                       0
# Rec Tributária                      0
# Impostos                            0
# IPTU                                0
# IRRF                                0
# ITBI                                0
# ISSQN                               0
# Taxas                               0
# Tx Poder de Policia                 0
# Tx Prestação de Servicos            0
# ...

# %%
findata2003.head()
# Out:
#    UG  NOME DO MUNICIPIO SIAFI  ... Resultado Acumulado Passivo Compensado
# 0   1            GUAJARA-MIRIM  ...                0.00          13,300.03
# 1   2  ALTO ALEGRE DOS PARECIS  ...                0.00               0.00
# 2   3              PORTO VELHO  ...      -97,932,401.21      41,876,050.79
# 3   4                  BURITIS  ...        5,197,602.72               0.00
# 4   5                JI-PARANA  ...       24,755,671.60       1,323,025.47
#
# [5 rows x 313 columns]

# %%
f=pd.to_numeric(findata2003.iloc[:,14].str.replace(',',''),downcast='float')
#f[0:3]
type(f)
# Out:
# pandas.core.series.Series

# %%
for i in range(findata2003.shape[0]):
    j=pd.to_numeric(findata2003.iloc[:,i].str.replace(',',''),downcast='float')
    df2=pd.concat([j],axis=1)

df2.drop(df.index[df.index==0],inplace=True)

df2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-2febe6e6c503> in <module>()
#       1 for i in range(findata2003.shape[0]):
# ----> 2     j=pd.to_numeric(findata2003.iloc[:,i].str.replace(',',''),downcast='float')
#       3     df2=pd.concat([j],axis=1)
#       4
#       5 df2.drop(df.index[df.index==0],inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# ...

# %%
pip install openai

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement util (from versions: none)
# ERROR: No matching distribution found for util

# %%
import os
import openai

# openai.api_key = "<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>"

# response = openai.Completion.create(
#   engine="davinci-codex",
#   prompt="\"\"\"\nUtil exposes the following:\nutil.openai() -> authenticates & returns the openai module, which has the following functions:\nopenai.Completion.create(\n    prompt=\"<my prompt>\", # The prompt to start completing from\n    max_tokens=123, # The max number of tokens to generate\n    temperature=1.0 # A measure of randomness\n    echo=True, # Whether to return the prompt in addition to the generated completion\n)\n\"\"\"\nimport util\n\"\"\"\nCreate an OpenAI completion starting from the prompt \"Once upon an AI\", no more than 5 tokens. Does not include the prompt.\n\"\"\"\n",
#   temperature=0,
#   max_tokens=64,
#   top_p=1.0,
#   frequency_penalty=0.0,
#   presence_penalty=0.0,
#   stop=["\"\"\""]
# )


import os
import openai
OPENAI_API_KEY='<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>'
openai.api_key = os.getenv(OPENAI_API_KEY)
#openai.api_key = " <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>"
#openai.api_key = "<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>"
#OPENAI_API_KEY="<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>"


response = openai.Completion.create(
  engine="davinci-codex",
  prompt=
  """
  Util exposes the following:
  util.openai() -> authenticates & returns the openai module, which has the following functions:
  openai.Completion.create(
    prompt="<my prompt>", # The prompt to start completing from
    max_tokens=123, # The max number of tokens to generate
    temperature=1.0 # A measure of randomness
    echo=True, # Whether to return the prompt in addition to the
    generated completion
  )
  import util
  """
  """
  Create an OpenAI completion starting from the prompt "Once upon an
  AI", no more than 5 tokens. Does not include the prompt.
  """,
  temperature=0,
  max_tokens=64,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=[" " " ""]
)
# Out:
#   File "<ipython-input-42-6b8d119c615a>", line 53
#     stop=[" " " ""]
#                    ^
# SyntaxError: EOL while scanning string literal

# %%
import os
import openai
OPENAI_API_KEY='<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>'
openai.api_key = os.getenv(OPENAI_API_KEY)

response = openai.Completion.create(
  engine="davinci-codex",
  prompt="\"\"\"\nUtil exposes the following:\nutil.openai() -> authenticates & returns the openai module, which has the following functions:\nopenai.Completion.create(\n    prompt=\"<my prompt>\", # The prompt to start completing from\n    max_tokens=123, # The max number of tokens to generate\n    temperature=1.0 # A measure of randomness\n    echo=True, # Whether to return the prompt in addition to the generated completion\n)\n\"\"\"\nimport util\n\"\"\"\nCreate an OpenAI completion starting from the prompt \"Once upon an AI\", no more than 5 tokens. Does not include the prompt.\n\"\"\"\n",
  temperature=0,
  max_tokens=64,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["\"\"\""]
)

completion = util.openai().Completion.create(
  prompt="Once upon an AI",
  max_tokens=5,
  temperature=1.0,
  echo=False,
)
print(completion)
"""
# Out:
#   File "<ipython-input-43-786edb3c4b46>", line 24
#     """
#        ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.Completion.create(
  engine="davinci-codex",
  prompt="\"\"\"\nUtil exposes the following:\nutil.openai() -> authenticates & returns the openai module, which has the following functions:\nopenai.Completion.create(\n    prompt=\"<my prompt>\", # The prompt to start completing from\n    max_tokens=123, # The max number of tokens to generate\n    temperature=1.0 # A measure of randomness\n    echo=True, # Whether to return the prompt in addition to the generated completion\n)\n\"\"\"\nimport util\n\"\"\"\nCreate an OpenAI completion starting from the prompt \"Once upon an AI\", no more than 5 tokens. Does not include the prompt.\n\"\"\"\n",
  temperature=0,
  max_tokens=64,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["\"\"\""]
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-44-5241e05ce510> in <module>()
#      12   frequency_penalty=0.0,
#      13   presence_penalty=0.0,
# ---> 14   stop=["\"\"\""]
#      15 )
#
# /usr/local/lib/python3.7/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      29         while True:
#      30             try:
# ---> 31                 return super().create(*args, **kwargs)
#      32             except TryAgain as e:
#      33                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.7/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, request_id, api_version, organization, **params)
#      60             api_base=api_base,
#      61             api_version=api_version,
# ---> 62             organization=organization,
# ...

# %%
receita2004=pd.read_csv('Receita2004.csv')
receita2004.head()
